# %% [markdown]
# # Mise à disposition du jeu de données stroke_dataset via une API REST

# %% [markdown]
# ## Description du dataset
#
# Le jeu de données utilisé provient de Kaggle : [Stroke Prediction Dataset](https://www.kaggle.com/datasets/fedesoriano/stroke-prediction-dataset).
# Il contient des données de patients avec différentes caractéristiques médicales et sociales, ainsi que l'information si le patient a subi un accident vasculaire cérébral (AVC) ou non.
#
# Télécharger les données et ajouter les dans un dossier data/.
#
# Les colonnes des données sont :
# - `id` : Identifiant unique du patient
# - `gender` : Sexe
# - `age` : Âge
# - `hypertension` : Présence d'hypertension (0 ou 1)
# - `heart_disease` : Présence de maladie cardiaque (0 ou 1)
# - `ever_married` : Statut marital
# - `work_type` : Type d'emploi
# - `Residence_type` : Urbaine ou rurale
# - `avg_glucose_level` : Moyenne du taux de glucose
# - `bmi` : Indice de masse corporelle
# - `smoking_status` : Statut tabagique
# - `stroke` : Présence d'AVC (0 ou 1)
#
# ## Projet
#
# Vous devez exposer les données patients du jeu de données via une API REST afin que les données soit utilisables par d'autres équipes (médecins, data science, étude, etc.).
#
# Cette API REST sera développée avec FastAPI et les spécifications sont les suivantes :
# | Méthode | Endpoint                                      | Fonctionnalité                                                                                                    |
# | ------- | --------------------------------------------- | ----------------------------------------------------------------------------------------------------------------- |
# | `GET`   | `/patients/{id}`                              | Récupère les détails d’un patient donné (via son identifiant unique)                                              |
# | `GET`   | `/patients?stroke=1&gender=Female&max_age=60` | Renvoie les patients filtrés selon plusieurs critères : AVC (oui/non), genre, âge maximal                         |
# | `GET`   | `/stats/`                                     | Fournit des statistiques agrégées sur les patients (ex. : nb total de patients, âge moyen, taux d’AVC, répartition hommes/femmes, etc.) |
#
#
#
# ---
#
# ## Quelques définitions
#
#
# 1. Qu’est-ce qu’une API REST ?
#
# - API signifie Application Programming Interface (Interface de Programmation d’Application). C’est un ensemble de règles et de protocoles qui permettent à des logiciels de communiquer entre eux.
# - REST signifie Representational State Transfer. C’est un style architectural pour concevoir des services web.
# Il en existe d'autres mais REST est celui que vous rencontrerez le plus souvent.
# - Vous avez utilisé une API REST via l'API Google Books.
#
# - A quoi sert une API REST ?
#
#     - Permet à différentes applications de communiquer facilement, même si elles sont écrites dans des langages différents.
#     - Permet d’accéder à des services distants (ex : bases de données, services web) de manière standardisée.
#     - Facilite la création d’applications modulaires et évolutives (front-end, back-end, mobile, etc.)
#
# 2. Principes clés d’une API REST
#
# - a. Utilisation du protocole HTTP
# Les échanges entre client et serveur utilisent des méthodes HTTP standard comme :
#
#     - GET : pour récupérer des données
#     - POST : pour envoyer ou créer des données
#     - PUT : pour mettre à jour des données
#     - DELETE : pour supprimer des données
#
# - b. Accès aux ressources via des URLs
#
# Chaque ressource (par exemple un livre, un utilisateur) est accessible via une URL unique.
#
# Exemple fictif:
#     https://api.example.com/books/123 pour accéder au livre d’identifiant 123.
#
# - c. Stateless (sans état)
#
# Le serveur ne conserve aucune information sur le client entre deux requêtes. Chaque requête doit contenir toutes les informations nécessaires.
#
# - d. Représentations des données
#
# Les données sont envoyées et reçues généralement en format JSON ou XML, qui sont faciles à lire et à manipuler.
#
# - e. Utilisation de codes status HTTP
#
# Chaque réponse du serveur est accompagnée d’un code HTTP indiquant le résultat de la requête. (cf [liste des codes](https://developer.mozilla.org/en-US/docs/Web/HTTP/Reference/Status))
#
# ## Outils utilisés
# 1. FastAPI
#
# FastAPI est un framework Python moderne, rapide et très utilisé dans le milieu professionnel pour construire des API REST.
#
# Il permet :
# - une définition simple des routes et des paramètres
# - La génération automatique de documentation interactive (Swagger UI)
# - FastAPI lit les requêtes entrantes, les traite avec ton code Python, et retourne une réponse HTTP (en JSON).
#
# 2. Uvicorn : exécute l'application FastAPI
#
# - Uvicorn est un serveur ASGI (Asynchronous Server Gateway Interface) : c'est une interface standard pour gérer les requêtes de manière asynchrone et performante, notamment utile pour les applications modernes.
# - Il attend les requêtes HTTP (par exemple depuis un navigateur), les transmet à FastAPI, et renvoie la réponse.
# - Uvicorn permet à l'API de fonctionner : sans Uvicorn ou un autre serveur, FastAPI ne peut pas fonctionner.
#
#
# 3. Swagger UI : l’interface de doc et test interactive
#
# - Swagger UI est généré automatiquement par FastAPI.
# - C’est une interface web qui permet de :
#     - Voir toutes les routes disponibles dans l'API
#     - Tester les routes en envoyant des requêtes sans écrire de code (bouton try it out)
#     - Voir les paramètres attendus et les formats de réponse
#
# 4. Résumé des interactions
#
# - Tester la route de base de l'API grâce à la commande :
# ```bash
#     poetry run fastapi dev stroke_api/main.py
# ```
#
# --> Qu'est-ce qu'il se passe derrière cette commande ?
#
# - Uvicorn démarre un serveur local
# - FastAPI génère automatiquement une interface : Swagger UI, accessible sur http://127.0.0.1:8000/docs qui affiche toutes les routes définies dans le code python FastAPI
# - Quand on clique sur "Try it out" dans Swagger UI, Swagger envoie une requête HTTP au serveur (ici Uvicorn)
# - Le serveur (Uvicorn) la reçoit, l’envoie à FastAPI, qui traite et renvoie une réponse
# - Swagger UI affiche la réponse de l’API (par ex : liste de patients)

# %% [markdown]
# ---
#
# Import des bibliothèques utiles au projet

# %%
import pandas as pd
from fastapi import FastAPI
import numpy as np

# %% [markdown]
# ## 1. Prétraitement des données / Data preprocessing
#
# Les données réelles sont rarement prêtes à être utilisées directement. Elles peuvent contenir des erreurs, des valeurs manquantes, des doublons, des formats incohérents, ou ne pas être adaptées au modèle ou au système cible.
#
# Le prétraitement consiste à nettoyer, structurer et transformer les données brutes avant de les exploiter dans un projet (modèle IA, API, visualisation, etc.).
#
# Vous avez déjà prétraité des données, petit rappel des éléments sur lesquels travailler dans un prétraitment classique et les méthodes pandas qu'il est possible d'utiliser pour les différentes étapes (des exeples d'utilisation des méthodes pandas sont disponibles dans la doc) :
# - explorer les données pour identifier les types de données, valeurs manquantes, incohérence ([info](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.info.html), [dtypes](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dtypes.html))
# - adapter les types si nécessaire ([astypes](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.astype.html))
# - identifier les doublons et les supprimer s'il y en a ([duplicated](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html), [drop_duplicates](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop_duplicates.html))
# - traiter les valeurs manquantes s'il y en a ([fillna](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.fillna.html), [dropna](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html), [replace](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.replace.html))
# - identifier les incohérences éventuelles (valeurs aberrantes/outliers) en vérifiant si les valeurs min, max, moyennes sont raisonnables (recherche internet si nécessaire) ([describe](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.describe.html)), et les traiter.
# - Traiter les valeurs aberrantes si vous en détectez ([loc](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html) pour récupérer les lignes qui répondent à une certaine condition, cf exemple ci-dessous)
#
#
# **Exemple df.loc :**
#
# Récupérer toutes les lignes de df telles que la valeur de "nom de colonne" >= 0
#
# ```df_subset = df.loc[stroke_data_df['nom de colonne'] >= 0]```

# %% [markdown]
# ---
# ### **TODO**
# 1.a. Prétraiter les données du dataset.
#
#
# 1.b. Documenter dans le README.md :
# - Les étapes de prétraitement,
# - Justification des choix concernant le traitement des valeurs manquantes (si besoin),
# - Liste des valeurs raisonnables utilisées pour détecter les valeurs aberrantes,
# - Justification des choix pour traiter les valeurs aberrantes (si besoin).
#
# 2.a. Chercher des infos sur le format de fichier parquet et indiquer les sources consultées :
# - Différence principale avec le format csv ?
# - Dans quels cas l'utiliser ?
# - Pourquoi c'est un format adapté aux gros volumes de données ?
#
# Différence principale avec le format csv ? </br>,
# Le format parquet transforme les données en binaire, compresse les données (donc moins volumineux), optimal pour traiter un grand nombre de données.
# Dans quels cas l'utiliser ? </br>,
# Principalement pour le stockage de données tabulaires.
# Pourquoi c'est un format adapté aux gros volumes de données ? </br>,
# Parce qu'il compresse les données.
#
# 2.b. Sauvegarder les données prétraiteées dans un fichier parquet ([to_parquet](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.to_parquet.html)).

# %%
# Prétraitement de données
import pandas as pd
df = pd.read_csv("data/healthcare-dataset-stroke-data-cleaned.csv")
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# 75%           114.090000    33.100000     0.000000
# max           271.740000    97.600000     1.000000

# %%
import pandas as pd

# Chargement du fichier
df = pd.read_csv("data/healthcare-dataset-stroke-data-cleaned.csv")

#  Afficher le nombre de doublons
print("Nombre de lignes dupliquées :", df.duplicated().sum())

#  Supprimer les doublons
df = df.drop_duplicates()

#  Afficher les premières lignes après nettoyage
print(df.head())
# Out:
# Nombre de lignes dupliquées : 0
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
print(f"Nombre de lignes avant suppression : {len(df)}")
df = df.drop_duplicates()
print(f"Nombre de lignes après suppression : {len(df)}")
# Out:
# Nombre de lignes avant suppression : 5110
# Nombre de lignes après suppression : 5110

# %%
  # Export de la copie csv en dataframe
df = pd.read_csv('data/healthcare-dataset-stroke-data-cleaned.csv')


# Fonction pour l'imputation de la catégorie d'âge
def impute_age_category(age):
    if age < 13:
        return 'enfant'
    elif age < 18:
        return 'ado'
    elif age <= 45:
        return 'adulte_21_45'
    elif age <= 65:
        return 'adulte_46_65'
    else:
        return 'senior'

# Création colonne & imputation des patients selon leur âge dans une catégorie d'âge
df['age_category'] = df['age'].apply(impute_age_category)

# AJOUT : imputation du statut fumeur pour les enfants
df.loc[df['age_category'] == 'enfant', 'smoking_status'] = 'never smoked'

# Calcul de la médiane de l'IMC selon la catégorie d'âge
bmi_medians = df.groupby('age_category')['bmi'].median()

# Fonction pour catégoriser le taux de glycémie
def impute_glucose_category(glucose):
    if glucose < 90:
        return 'faible'
    elif glucose <= 125:
        return 'normal'
    else:
        return 'élevé'

# Création colonne & imputation dans les catégories (glycémie)
df['glucose_category'] = df['avg_glucose_level'].apply(impute_glucose_category)

#selon le genre, statut SP, catégorie d'âge et taux de glycémie
bmi_medians_multi = (
    df.groupby(['gender', 'work_type', 'age_category', 'glucose_category'])['bmi']
    .median()
    .round(1)
    .reset_index()
)


# Fusion avec le dataset nettoyé
df = df.merge(
    bmi_medians_multi,
    on=['gender', 'work_type', 'age_category', 'glucose_category'],
    how='left',
    suffixes=('', '_impute')
)

# Remplacement des valeurs manquantes
df['bmi'] = df['bmi'].fillna(df['bmi_impute'])
df.drop(columns=['bmi_impute'], inplace=True)

# Export et vérification
print('Valeur manquantes restantes: ', df['bmi'].isna().sum())
df = df.to_csv('df_final_test.csv')
df = pd.read_csv('df_final_test.csv')
# Out:
# Valeur manquantes restantes:  0

# %%
import pandas as pd

df = pd.read_csv("df_final_test.csv")

#  Nombre de valeurs manquantes par colonne
print(df.isnull().sum())

#  En pourcentage 
print((df.isnull().sum() / len(df)) * 100)
# Out:
# Unnamed: 0           0
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# age_category         0
# glucose_category     0
# dtype: int64
# Unnamed: 0           0.0
# id                   0.0
# gender               0.0
# age                  0.0
# hypertension         0.0
# heart_disease        0.0
# ever_married         0.0
# work_type            0.0
# Residence_type       0.0
# avg_glucose_level    0.0
# bmi                  0.0
# smoking_status       0.0
# stroke               0.0
# age_category         0.0
# glucose_category     0.0
# dtype: float64

# %%
# BMI extrêmes
bmi_out = df[(df["bmi"] > 60) | (df["bmi"] < 12)]
print(bmi_out)

# Age <1 an
age_out = df[df["age"] < 1]
print(age_out)
# Out:
#       Unnamed: 0     id  gender    age  hypertension  heart_disease  \
# 270          270  72911  Female  57.00             1              0
# 358          358  66333    Male  52.00             0              0
# 466          466   1307  Female  61.00             1              0
# 544          544    545    Male  42.00             0              0
# 928          928  41097  Female  23.00             1              0
# 1559        1559  37759  Female  53.00             0              0
# 1609        1609  38043  Female   1.24             0              0
# 2128        2128  56420    Male  17.00             1              0
# 2187        2187  59993    Male  40.00             0              0
# 2764        2764  20292  Female  24.00             0              0
# 2840        2840  65895  Female  52.00             0              0
# 3307        3307   3205  Female  79.00             0              0
# 3825        3825  72784  Female  52.00             0              0
# 4188        4188  70670  Female  27.00             0              0
# 4209        4209  51856    Male  38.00             1              0
# 4838        4838   5131  Female  51.00             0              0
#
#      ever_married      work_type Residence_type  avg_glucose_level   bmi  \
# 270           Yes        Private          Rural             129.54  60.9
# 358           Yes  Self-employed          Urban              78.40  64.8
# 466           Yes        Private          Rural             170.05  60.2
# 544           Yes        Private          Rural             210.48  71.9
# 928            No        Private          Urban              70.03  78.0
# 1559          Yes        Private          Rural              72.63  66.8
# 1609           No       children          Rural             122.04  10.3
# 2128           No        Private          Rural              61.67  97.6
# 2187          Yes        Private          Rural              60.96  11.5
# 2764          Yes        Private          Urban              85.55  63.3
# 2840          Yes        Private          Urban              98.27  61.2
# 3307          Yes  Self-employed          Urban              79.03  11.3
# 3825          Yes        Private          Rural             118.46  61.6
# 4188          Yes        Private          Rural              57.96  64.4
# 4209          Yes        Private          Rural              56.90  92.0
# 4838          Yes        Private          Urban             107.72  60.9
#
#      smoking_status  stroke  age_category glucose_category
# 270          smokes       0  adulte_46_65            élevé
# 358    never smoked       0  adulte_46_65           faible
# 466          smokes       0  adulte_46_65            élevé
# 544    never smoked       0  adulte_21_45            élevé
# 928          smokes       0  adulte_21_45           faible
# 1559        Unknown       0  adulte_46_65           faible
# 1609   never smoked       0        enfant           normal
# 2128        Unknown       0           ado           faible
# 2187   never smoked       0  adulte_21_45           faible
# 2764   never smoked       0  adulte_21_45           faible
# 2840        Unknown       0  adulte_46_65           normal
# 3307        Unknown       0        senior           faible
# 3825         smokes       0  adulte_46_65           normal
# 4188   never smoked       0  adulte_21_45           faible
# 4209   never smoked       0  adulte_21_45           faible
# 4838        Unknown       0  adulte_46_65           normal
#       Unnamed: 0     id  gender   age  hypertension  heart_disease  \
# 363          363   7559  Female  0.64             0              0
# 376          376  22706  Female  0.88             0              0
# 564          564  61511  Female  0.32             0              0
# 982          982  54747    Male  0.88             0              0
# 996          996  53279    Male  0.24             0              0
# 1093        1093  66772  Female  0.32             0              0
# 1206        1206  68908  Female  0.72             0              0
# 1317        1317  30084    Male  0.80             0              0
# 1600        1600  40544    Male  0.40             0              0
# 1614        1614  47350  Female  0.08             0              0
# 1808        1808  53126  Female  0.64             0              0
# 1975        1975   6596    Male  0.56             0              0
# 1999        1999  42500    Male  0.24             0              0
# 2008        2008  67099    Male  0.56             0              0
# 2012        2012  34261    Male  0.64             0              0
# 2030        2030  38920    Male  0.48             0              0
# 2358        2358   1275    Male  0.88             0              0
# 2481        2481  20257    Male  0.88             0              0
# 2490        2490  48406    Male  0.88             0              0
# 2579        2579  68382    Male  0.32             0              0
# 2630        2630  61836  Female  0.80             0              0
# 2801        2801    760    Male  0.80             0              0
# 2875        2875  42938    Male  0.64             0              0
# 2898        2898  64974    Male  0.24             0              0
# 3251        3251  14877    Male  0.56             0              0
# 3295        3295  29955    Male  0.08             0              0
# 3392        3392  11371    Male  0.24             0              0
# 3440        3440  18837    Male  0.56             0              0
# 3618        3618  22877    Male  0.16             0              0
# 3626        3626  23360    Male  0.80             0              0
# 3859        3859  13857    Male  0.32             0              0
# 3894        3894  69435  Female  0.56             0              0
# 3968        3968  41500    Male  0.16             0              0
# 4007        4007  43282    Male  0.72             0              0
# 4021        4021   8247    Male  0.16             0              0
# 4053        4053  40255  Female  0.48             0              0
# 4293        4293  69222    Male  0.24             0              0
# 4409        4409   1953  Female  0.72             0              0
# 4581        4581  15728  Female  0.40             0              0
# 4645        4645  25783  Female  0.48             0              0
# 4910        4910  37622  Female  0.32             0              0
# 4929        4929  29487    Male  0.72             0              0
# 5089        5089  56714  Female  0.72             0              0
#
#      ever_married work_type Residence_type  avg_glucose_level   bmi  \
# 363            No  children          Urban              83.82  24.9
# 376            No  children          Rural              88.11  15.5
# 564            No  children          Rural              73.71  16.2
# 982            No  children          Rural             157.57  19.2
# 996            No  children          Rural             118.87  16.3
# 1093           No  children          Rural              55.86  16.0
# 1206           No  children          Urban              66.36  23.0
# 1317           No  children          Rural              98.67  17.5
# 1600           No  children          Urban             109.56  14.3
# 1614           No  children          Urban             139.67  14.1
# 1808           No  children          Urban              62.27  17.3
# 1975           No  children          Rural             111.77  21.1
# 1999           No  children          Rural             146.97  18.5
# 2008           No  children          Rural              57.02  20.7
# 2012           No  children          Rural              86.74  16.2
# 2030           No  children          Urban              73.02  18.4
# 2358           No  children          Urban             112.19  18.9
# 2481           No  children          Urban              90.62  22.4
# 2490           No  children          Urban              85.38  23.4
# 2579           No  children          Urban             127.78  20.8
# 2630           No  children          Urban             106.59  15.5
# 2801           No  children          Urban              75.22  33.1
# 2875           No  children          Urban              60.40  17.3
# 2898           No  children          Urban              58.35  18.6
# 3251           No  children          Rural             127.23  20.1
# 3295           No  children          Rural              70.33  16.9
# 3392           No  children          Urban              89.28  14.2
# 3440           No  children          Urban              98.23  14.1
# 3618           No  children          Urban             114.71  17.4
# 3626           No  children          Rural             114.54  15.1
# 3859           No  children          Urban              89.04  17.8
# 3894           No  children          Urban              80.92  18.3
# 3968           No  children          Rural              69.79  13.0
# 4007           No  children          Rural             159.79  19.9
# 4021           No  children          Urban             109.52  13.9
# 4053           No  children          Rural             118.75  17.4
# 4293           No  children          Urban              57.09  19.4
# 4409           No  children          Rural             112.19  20.1
# 4581           No  children          Rural              85.65  17.4
# 4645           No  children          Rural              94.06  14.8
# 4910           No  children          Urban             108.63  19.6
# 4929           No  children          Urban              80.08  16.4
# 5089           No  children          Rural              62.13  16.8
#
#      smoking_status  stroke age_category glucose_category
# 363    never smoked       0       enfant           faible
# 376    never smoked       0       enfant           faible
# 564    never smoked       0       enfant           faible
# 982    never smoked       0       enfant            élevé
# 996    never smoked       0       enfant           normal
# 1093   never smoked       0       enfant           faible
# 1206   never smoked       0       enfant           faible
# 1317   never smoked       0       enfant           normal
# 1600   never smoked       0       enfant           normal
# 1614   never smoked       0       enfant            élevé
# 1808   never smoked       0       enfant           faible
# 1975   never smoked       0       enfant           normal
# 1999   never smoked       0       enfant            élevé
# 2008   never smoked       0       enfant           faible
# 2012   never smoked       0       enfant           faible
# 2030   never smoked       0       enfant           faible
# 2358   never smoked       0       enfant           normal
# 2481   never smoked       0       enfant           normal
# 2490   never smoked       0       enfant           faible
# 2579   never smoked       0       enfant            élevé
# 2630   never smoked       0       enfant           normal
# 2801   never smoked       0       enfant           faible
# 2875   never smoked       0       enfant           faible
# 2898   never smoked       0       enfant           faible
# 3251   never smoked       0       enfant            élevé
# 3295   never smoked       0       enfant           faible
# 3392   never smoked       0       enfant           faible
# 3440   never smoked       0       enfant           normal
# 3618   never smoked       0       enfant           normal
# 3626   never smoked       0       enfant           normal
# 3859   never smoked       0       enfant           faible
# 3894   never smoked       0       enfant           faible
# 3968   never smoked       0       enfant           faible
# 4007   never smoked       0       enfant            élevé
# 4021   never smoked       0       enfant           normal
# 4053   never smoked       0       enfant           normal
# 4293   never smoked       0       enfant           faible
# 4409   never smoked       0       enfant           normal
# 4581   never smoked       0       enfant           faible
# 4645   never smoked       0       enfant           normal
# 4910   never smoked       0       enfant           normal
# 4929   never smoked       0       enfant           faible
# 5089   never smoked       0       enfant           faible

# %%
# Filtrer les enfants (moins de 18 ans)
enfants = df[df["age"] < 1]

# Trier par BMI décroissant
enfants_bmi_haut = enfants.sort_values(by="bmi", ascending=False)

# Afficher les 5 enfants avec le BMI le plus élevé
print(enfants_bmi_haut.head())
# Out:
#       Unnamed: 0     id  gender   age  hypertension  heart_disease  \
# 2801        2801    760    Male  0.80             0              0
# 363          363   7559  Female  0.64             0              0
# 2490        2490  48406    Male  0.88             0              0
# 1206        1206  68908  Female  0.72             0              0
# 2481        2481  20257    Male  0.88             0              0
#
#      ever_married work_type Residence_type  avg_glucose_level   bmi  \
# 2801           No  children          Urban              75.22  33.1
# 363            No  children          Urban              83.82  24.9
# 2490           No  children          Urban              85.38  23.4
# 1206           No  children          Urban              66.36  23.0
# 2481           No  children          Urban              90.62  22.4
#
#      smoking_status  stroke age_category glucose_category
# 2801   never smoked       0       enfant           faible
# 363    never smoked       0       enfant           faible
# 2490   never smoked       0       enfant           faible
# 1206   never smoked       0       enfant           faible
# 2481   never smoked       0       enfant           normal

# %%
# Supprimer les lignes où "gender" est "Other"
df = df[df["gender"] != "Other"]

# Vérifier les valeurs restantes
print(df["gender"].unique())
# Out:
# ['Male' 'Female']

# %% [markdown]
# -----
# ## Développement de l'API
#
# A présent que les données sont propres, on peut débuter la création de l'API.
#
# Pour cela, vous allez avoir besoin de quelques fonctions permettant de filtrer les données.
#
# Vous allez les définir ci-dessous, ce qui vous permettra de les tester puis les fonctions seront reportées dans le fichier filters.py.

# %% [markdown]
# ## Route `/patients/`
# - Cette route retourne une liste filtrée de patients
# - On souhaite pouvoir filtrer par `gender`, `stroke` ou `max_age`
#
# L'objectif est ici de définir une fonction python qui prend en entrée les paramètres optionnels : _gender_, *stroke*, *max_age* et qui renvoie un dictionnaire filtré des données.
#
# On décompose la rédaction de cette fonction en plusieurs étapes.
#
# Dans un premier temps, écrire et tester les filtres que l'on souhaite appliquer sur les données (utiliser [loc](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html))

# %%
# Filtrer le dataframe pour ne garder que les patients pour lesquels "stroke=1"
df= pd.read_csv('df_final_test.csv')

# %%
stroke = df.loc[df['stroke'] == 1]
print(stroke)
# Out:
#      Unnamed: 0     id  gender   age  hypertension  heart_disease  \
# 0             0   9046    Male  67.0             0              1
# 1             1  51676  Female  61.0             0              0
# 2             2  31112    Male  80.0             0              1
# 3             3  60182  Female  49.0             0              0
# 4             4   1665  Female  79.0             1              0
# ..          ...    ...     ...   ...           ...            ...
# 244         244  17739    Male  57.0             0              0
# 245         245  49669  Female  14.0             0              0
# 246         246  27153  Female  75.0             0              0
# 247         247  34060    Male  71.0             1              0
# 248         248  43424  Female  78.0             0              0
#
#     ever_married      work_type Residence_type  avg_glucose_level   bmi  \
# 0            Yes        Private          Urban             228.69  36.6
# 1            Yes  Self-employed          Rural             202.21  33.5
# 2            Yes        Private          Rural             105.92  32.5
# 3            Yes        Private          Urban             171.23  34.4
# 4            Yes  Self-employed          Rural             174.12  24.0
# ..           ...            ...            ...                ...   ...
# 244          Yes        Private          Rural              84.96  36.7
# 245           No       children          Rural              57.93  30.9
# 246          Yes  Self-employed          Rural              78.80  29.3
# 247          Yes  Self-employed          Rural              87.80  27.0
# 248          Yes        Private          Rural              78.81  19.6
#
#       smoking_status  stroke  age_category glucose_category
# 0    formerly smoked       1        senior            élevé
# 1       never smoked       1  adulte_46_65            élevé
# 2       never smoked       1        senior           normal
# 3             smokes       1  adulte_46_65            élevé
# 4       never smoked       1        senior            élevé
# ..               ...     ...           ...              ...
# 244          Unknown       1  adulte_46_65           faible
# 245          Unknown       1           ado           faible
# 246  formerly smoked       1        senior           faible
# 247          Unknown       1        senior           faible
# 248          Unknown       1        senior           faible
#
# [249 rows x 15 columns]

# %%
# Filtrer les données pour ne garder que les patients pour lesquels "gender="male"
gender = df.loc[df['gender'] == 'Male']
print(gender)
# Out:
#       Unnamed: 0     id gender   age  hypertension  heart_disease  \
# 0              0   9046   Male  67.0             0              1
# 2              2  31112   Male  80.0             0              1
# 5              5  56669   Male  81.0             0              0
# 6              6  53882   Male  74.0             1              1
# 13            13   8213   Male  78.0             0              1
# ...          ...    ...    ...   ...           ...            ...
# 5097        5097  64520   Male  68.0             0              0
# 5098        5098    579   Male   9.0             0              0
# 5099        5099   7293   Male  40.0             0              0
# 5100        5100  68398   Male  82.0             1              0
# 5108        5108  37544   Male  51.0             0              0
#
#      ever_married      work_type Residence_type  avg_glucose_level   bmi  \
# 0             Yes        Private          Urban             228.69  36.6
# 2             Yes        Private          Rural             105.92  32.5
# 5             Yes        Private          Urban             186.21  29.0
# 6             Yes        Private          Rural              70.09  27.4
# 13            Yes        Private          Urban             219.84  30.3
# ...           ...            ...            ...                ...   ...
# 5097          Yes  Self-employed          Urban              91.68  40.8
# 5098           No       children          Urban              71.88  17.5
# 5099          Yes        Private          Rural              83.94  28.4
# 5100          Yes  Self-employed          Rural              71.97  28.3
# 5108          Yes        Private          Rural             166.29  25.6
#
#        smoking_status  stroke  age_category glucose_category
# 0     formerly smoked       1        senior            élevé
# 2        never smoked       1        senior           normal
# 5     formerly smoked       1        senior            élevé
# 6        never smoked       1        senior           faible
# 13            Unknown       1        senior            élevé
# ...               ...     ...           ...              ...
# 5097          Unknown       0        senior           normal
# 5098     never smoked       0        enfant           faible
# 5099           smokes       0  adulte_21_45           faible
# 5100     never smoked       0        senior           faible
# 5108  formerly smoked       0  adulte_46_65            élevé
#
# [2115 rows x 15 columns]

# %%
# Filtrer les données pour ne garder que les patients tels que "age <= max_age"

max_age = df ['age'].max()
print(max_age)
df_max_age = df.loc[df['age'] <= max_age]
print(df_max_age)
# Out:
# 82.0
#       Unnamed: 0     id  gender   age  hypertension  heart_disease  \
# 0              0   9046    Male  67.0             0              1
# 1              1  51676  Female  61.0             0              0
# 2              2  31112    Male  80.0             0              1
# 3              3  60182  Female  49.0             0              0
# 4              4   1665  Female  79.0             1              0
# ...          ...    ...     ...   ...           ...            ...
# 5105        5105  18234  Female  80.0             1              0
# 5106        5106  44873  Female  81.0             0              0
# 5107        5107  19723  Female  35.0             0              0
# 5108        5108  37544    Male  51.0             0              0
# 5109        5109  44679  Female  44.0             0              0
#
#      ever_married      work_type Residence_type  avg_glucose_level   bmi  \
# 0             Yes        Private          Urban             228.69  36.6
# 1             Yes  Self-employed          Rural             202.21  33.5
# 2             Yes        Private          Rural             105.92  32.5
# 3             Yes        Private          Urban             171.23  34.4
# 4             Yes  Self-employed          Rural             174.12  24.0
# ...           ...            ...            ...                ...   ...
# 5105          Yes        Private          Urban              83.75  26.8
# 5106          Yes  Self-employed          Urban             125.20  40.0
# 5107          Yes  Self-employed          Rural              82.99  30.6
# 5108          Yes        Private          Rural             166.29  25.6
# 5109          Yes       Govt_job          Urban              85.28  26.2
#
#        smoking_status  stroke  age_category glucose_category
# 0     formerly smoked       1        senior            élevé
# 1        never smoked       1  adulte_46_65            élevé
# 2        never smoked       1        senior           normal
# 3              smokes       1  adulte_46_65            élevé
# 4        never smoked       1        senior            élevé
# ...               ...     ...           ...              ...
# 5105     never smoked       0        senior           faible
# 5106     never smoked       0        senior            élevé
# 5107     never smoked       0  adulte_21_45           faible
# 5108  formerly smoked       0  adulte_46_65            élevé
# 5109          Unknown       0  adulte_21_45           faible
#
# [5110 rows x 15 columns]

# %% [markdown]
# Appliquer successivement les 3 filtres au sein d'une fonction qui prend en entrée le dataframe, _stroke_, _gender_, _max_age_ et qui renvoie une liste de dictionnaire de patients (utiliser la méthode pandas [to_dict](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_dict.html)).
#
# Exemple
# ```
# [{'id': 9046,
#   'gender': 'Male',
#   'age': 67.0,
#   ...
#   'smoking_status': 'formerly smoked',
#   'stroke': 1},
#  {'id': 31112,
#   'gender': 'Male',
#   'age': 80.0,
#   ...
#   'smoking_status': 'formerly smoked',
#   'stroke': 1}]
#   ```

# %%
#def filter_patient(df, max_age, gender, stroke):

def filter_patients(df: pd.DataFrame, gender: str, max_age: float, stroke: int) -> list[dict]:
    
    filtered_df = df[
        (df['stroke'] == stroke) &
        (df['gender'] == gender) &
        (df['age'] <= max_age)
    ]

    return filtered_df.to_dict(orient='records')

filtre1 = filter_patients(df, max_age= 80,gender= 'Male', stroke=1)
print(filtre1)
# Out:
# [{'Unnamed: 0': 0, 'id': 9046, 'gender': 'Male', 'age': 67.0, 'hypertension': 0, 'heart_disease': 1, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 228.69, 'bmi': 36.6, 'smoking_status': 'formerly smoked', 'stroke': 1, 'age_category': 'senior', 'glucose_category': 'élevé'}, {'Unnamed: 0': 2, 'id': 31112, 'gender': 'Male', 'age': 80.0, 'hypertension': 0, 'heart_disease': 1, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 105.92, 'bmi': 32.5, 'smoking_status': 'never smoked', 'stroke': 1, 'age_category': 'senior', 'glucose_category': 'normal'}, {'Unnamed: 0': 6, 'id': 53882, 'gender': 'Male', 'age': 74.0, 'hypertension': 1, 'heart_disease': 1, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 70.09, 'bmi': 27.4, 'smoking_status': 'never smoked', 'stroke': 1, 'age_category': 'senior', 'glucose_category': 'faible'}, {'Unnamed: 0': 13, 'id': 8213, 'gender': 'Male', 'age': 78.0, 'hypertension': 0, 'heart_disease': 1, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 219.84, 'bmi': 30.3, 'smoking_status': 'Unknown', 'stroke': 1, 'age_category': 'senior', 'glucose_category': 'élevé'}, {'Unnamed: 0': 16, 'id': 56112, 'gender': 'Male', 'age': 64.0, 'hypertension': 0, 'heart_disease': 1, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 191.61, 'bmi': 37.5, 'smoking_status': 'smokes', 'stroke': 1, 'age_category': 'adulte_46_65', 'glucose_category': 'élevé'}, {'Unnamed: 0': 17, 'id': 34120, 'gender': 'Male', 'age': 75.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 221.29, 'bmi': 25.8, 'smoking_status': 'smokes', 'stroke': 1, 'age_category': 'senior', 'glucose_category': 'élevé'}, {'Unnamed: 0': 19, 'id': 25226, 'gender': 'Male', 'age': 57.0, 'hypertension': 0, 'heart_disease': 1, 'ever_married': 'No', 'work_type': 'Govt_job', 'Residence_type': 'Urban', 'avg_glucose_level': 217.08, 'bmi': 33.6, 'smoking_status': 'Unknown', 'stroke': 1, 'age_category': 'adulte_46_65', 'glucose_category': 'élevé'}, {'Unnamed: 0': 24, 'id': 4219, 'gender': 'Male', 'age': 71.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 102.87, 'bmi': 27.2, 'smoking_status': 'formerly smoked', 'stroke': 1, 'age_category': 'senior', 'glucose_category': 'normal'}, {'Unnamed: 0': 25, 'id': 70822, 'gender': 'Male', 'age': 80.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Self-employed', 'Residence_type': 'Rural', 'avg_glucose_level': 104.12, 'bmi': 23.5, 'smoking_status': 'never smoked', 'stroke': 1, 'age_category': 'senior', 'glucose_category': 'normal'}, {'Unnamed: 0': 27, 'id': 61843, 'gender': 'Male', 'age': 58.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 189.84, 'bmi': 33.3, 'smoking_status': 'Unknown', 'stroke': 1, 'age_category': 'adulte_46_65', 'glucose_category': 'élevé'}, {'Unnamed: 0': 28, 'id': 54827, 'gender': 'Male', 'age': 69.0, 'hypertension': 0, 'heart_disease': 1, 'ever_married': 'Yes', 'work_type': 'Self-employed', 'Residence_type': 'Urban', 'avg_glucose_level': 195.23, 'bmi': 28.3, 'smoking_status': 'smokes', 'stroke': 1, 'age_category': 'senior', 'glucose_category': 'élevé'}, {'Unnamed: 0': 29, 'id': 69160, 'gender': 'Male', 'age': 59.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 211.78, 'bmi': 33.3, 'smoking_status': 'formerly smoked', 'stroke': 1, 'age_category': 'adulte_46_65', 'glucose_category': 'élevé'}, {'Unnamed: 0': 30, 'id': 43717, 'gender': 'Male', 'age': 57.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type':  ...

# %% [markdown]
# A présent on souhaite ajouter des informations sur les types des paramètres et valeurs de retour de la fonction pour faciliter sa compréhension et son utilisation, ce qu’on appelle l’annotation de type (type hinting).
#
# Cette pratique facilite la lecture et la maintenance du code.
#
# Quels changements pour la fonction ?
#
# A la suite de chaque paramètre, on ajoute le type attendu pour le paramètre. À la suite des paramètres on ajoute le type de ce que qui est retourné par la fonction, dans l'exemple ici :
#
# ```def filter_patient(stroke_data_df: pd.DataFrame, gender: str, etc) -> list[dict]```
#
# Ajouter les types dans la définition de la fonction.

# %% [markdown]
# Tester la fonction en ne mettant pas de valeur pour *max_age*.
#
# Que se passe-t-il ?

# %%
#def filter_patient(df, max_age, gender, stroke):

def filter_patients(df: pd.DataFrame, gender: str, max_age: float, stroke: int) -> list[dict]:
    
    filtered_df = df[
        (df['stroke'] == stroke) &
        (df['gender'] == gender) &
        (df['age'] <= max_age)
    ]

    return filtered_df.to_dict(orient='records')

filtre1 = filter_patients(df, max_age,gender= 'Male', stroke=1)
print(filtre1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 13
#       5     filtered_df = df[
#       6         (df['stroke'] == stroke) &
#       7         (df['gender'] == gender) &
#       8         (df['age'] <= max_age)
#       9     ]
#      11     return filtered_df.to_dict(orient='records')
# ---> 13 filtre1 = filter_patients(df, max_age,gender= 'Male', stroke=1)
#      14 print(filtre1)
#
# TypeError: filter_patients() got multiple values for argument 'gender'

# %% [markdown]
# Dans la fonction écrite ci-dessus, chaque paramètre est obligatoire.
#
# On souhaite pouvoir filtrer les patients sur 0, 1 ou 2 des paramètres de la fonction (filtrer seulement sur *max_age*  mais ne pas appliquer de filtres sur _gender_ et _stroke_ par exemple).
#
# On peut rendre optionnel les paramètres d'un fonction en choisissant une valeur par défault. Si on utilise la fonction en n'utilisant pas ces paramètres alors la valeur par défault est utilisé.
#
# Copier coller votre fonction ci-dessous et ajouter en paramètre : `max_age=None`
#
# et ajouter la condition suivante **avant le filtre** sur `max_age` :
#
# ```if max_age is not None : ```
#
# Si la fonction _filter_patient_ est appelée sans argument *max_age*, alors le filtre sur *max_age* n'est pas appliqué.
#
# Il est tout à fait possible de définir une valeur par défault par exemple 30 ans : dans ce cas si la fonction est appelée sans argument *max_age*, alors par défault on filtre les patients ayant moins de 30 ans.
#
# **ATTENTION :** Les paramètres optionnels doivent toujours être à la fin de la liste de paramètres.

# %%
def filter_patients(df: pd.DataFrame, gender: str, stroke: int, max_age: float = None) -> list[dict]:
    filtered_df = df[
        (df['stroke'] == stroke) &
        (df['gender'] == gender)
    ]

    if max_age is not None:
        filtered_df = filtered_df[filtered_df['age'] < max_age]

    return filtered_df.to_dict(orient='records')

# Appel de la fonction : patients de genre 'Female', stroke=0, moins de 30 ans
patients = filter_patients(df, gender='Female', stroke=0, max_age=30)

# Affichage
print("Patients filtrés :")
for patient in patients:
    print(patient)
# Out:
# Patients filtrés :
# {'Unnamed: 0': 251, 'id': 16523, 'gender': 'Female', 'age': 8.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 110.89, 'bmi': 17.6, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'normal'}
# {'Unnamed: 0': 265, 'id': 19584, 'gender': 'Female', 'age': 20.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 84.62, 'bmi': 19.7, 'smoking_status': 'smokes', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 274, 'id': 70336, 'gender': 'Female', 'age': 25.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 60.84, 'bmi': 24.5, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 282, 'id': 33759, 'gender': 'Female', 'age': 3.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 73.74, 'bmi': 16.0, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 286, 'id': 36811, 'gender': 'Female', 'age': 23.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 94.09, 'bmi': 30.9, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 288, 'id': 70970, 'gender': 'Female', 'age': 17.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Self-employed', 'Residence_type': 'Urban', 'avg_glucose_level': 82.18, 'bmi': 23.4, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'faible'}
# {'Unnamed: 0': 292, 'id': 44338, 'gender': 'Female', 'age': 16.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 110.63, 'bmi': 19.5, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'normal'}
# {'Unnamed: 0': 294, 'id': 34974, 'gender': 'Female', 'age': 22.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 79.81, 'bmi': 27.7, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 306, 'id': 16371, 'gender': 'Female', 'age': 13.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 75.42, 'bmi': 40.1, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'faible'}
# {'Unnamed: 0': 312, 'id': 68249, 'gender': 'Female', 'age': 27.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 85.6, 'bmi': 21.4, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 319, 'id': 1686, 'gender': 'Female', 'age': 29.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 71.89, 'bmi': 27.6, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 322, 'id': 21956, 'gender': 'Female', 'age': 22.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 69.94, 'bmi': 22.8, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 328, 'id': 29865, 'gender': 'Female', 'age': 21.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 89.44, 'bmi': 21.9, 'smoking_status': 'smokes', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 329, 'id': 54918, 'gender': 'Female', 'age': 18.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 111.38, 'bmi': 38.4, 'smoking_status': 'smokes', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 340, 'id': 10449, 'gender': 'Female', 'age': 24.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 75.23, 'bmi': 29.0, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 345, 'id': 9487, 'gender': 'Female', 'age': 23.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 99.92, 'bmi': 25.8, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 348, 'id': 28102, 'gender': 'Female', 'age': 25.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 66.3, 'bmi': 27.2, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 352, 'id': 40670, 'gender': 'Female', 'age': 20.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 96.57, 'bmi': 34.1, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 359, 'id': 46785, 'gender': 'Female', 'age': 29.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 63.69, 'bmi': 28.1, 'smoking_status': 'smokes', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 363, 'id': 7559, 'gender': 'Female', 'age': 0.64, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 83.82, 'bmi': 24.9, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 369, 'id': 8171, 'gender': 'Female', 'age': 4.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 93.25, 'bmi': 16.6, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'normal'}
# {'Unnamed: 0': 371, 'id': 43232, 'gender': 'Female', 'age': 18.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 80.05, 'bmi': 24.2, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 373, 'id': 34402, 'gender': 'Female', 'age': 23.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 91.97, 'bmi': 21.6, 'smoking_status': 'formerly smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 376, 'id': 22706, 'gender': 'Female', 'age': 0.88, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 88.11, 'bmi': 15.5, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 378, 'id': 28637, 'gender': 'Female', 'age': 14.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 72.36, 'bmi': 20.5, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'faible'}
# {'Unnamed: 0': 394, 'id': 5708, 'gender': 'Female', 'age': 20.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 91.6, 'bmi': 28.1, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 395, 'id': 23462, 'gender': 'Female', 'age': 17.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 87.52, 'bmi': 39.2, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'faible'}
# {'Unnamed: 0': 400, 'id': 65357, 'gender': 'Female', 'age': 5.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 84.59, 'bmi': 17.7, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 401, 'id': 49465, 'gender': 'Female', 'age': 13.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 70.16, 'bmi': 21.2, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'faible'}
# {'Unnamed: 0': 402, 'id': 31143, 'gender': 'Female', 'age': 22.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 107.52, 'bmi': 41.6, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 407, 'id': 36007, 'gender': 'Female', 'age': 21.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 101.37, 'bmi': 37.9, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 408, 'id': 14123, 'gender': 'Female', 'age': 22.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 105.22, 'bmi': 31.1, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 416, 'id': 27029, 'gender': 'Female', 'age': 3.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 73.2, 'bmi': 16.8, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 418, 'id': 45719, 'gender': 'Female', 'age': 22.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 82.0, 'bmi': 26.4, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 419, 'id': 129, 'gender': 'Female', 'age': 24.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 97.55, 'bmi': 26.2, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 421, 'id': 530, 'gender': 'Female', 'age': 12.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 75.22, 'bmi': 20.9, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 425, 'id': 6107, 'gender': 'Female', 'age': 5.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 77.88, 'bmi': 13.8, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 437, 'id': 5010, 'gender': 'Female', 'age': 2.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 92.48, 'bmi': 18.0, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'normal'}
# {'Unnamed: 0': 440, 'id': 56681, 'gender': 'Female', 'age': 22.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 130.34, 'bmi': 22.0, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'élevé'}
# {'Unnamed: 0': 441, 'id': 56716, 'gender': 'Female', 'age': 26.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 82.59, 'bmi': 29.4, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 459, 'id': 48272, 'gender': 'Female', 'age': 11.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 87.51, 'bmi': 24.4, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 460, 'id': 2893, 'gender': 'Female', 'age': 7.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 72.35, 'bmi': 17.0, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 461, 'id': 34376, 'gender': 'Female', 'age': 16.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 113.47, 'bmi': 19.5, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'normal'}
# {'Unnamed: 0': 471, 'id': 69687, 'gender': 'Female', 'age': 18.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Self-employed', 'Residence_type': 'Rural', 'avg_glucose_level': 93.88, 'bmi': 22.2, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 493, 'id': 66570, 'gender': 'Female', 'age': 23.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 69.24, 'bmi': 51.0, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 497, 'id': 37832, 'gender': 'Female', 'age': 14.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 129.53, 'bmi': 21.3, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'élevé'}
# {'Unnamed: 0': 498, 'id': 21058, 'gender': 'Female', 'age': 15.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 114.53, 'bmi': 29.1, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'normal'}
# {'Unnamed: 0': 515, 'id': 67733, 'gender': 'Female', 'age': 28.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 183.45, 'bmi': 40.5, 'smoking_status': 'smokes', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'élevé'}
# {'Unnamed: 0': 525, 'id': 29933, 'gender': 'Female', 'age': 5.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 86.11, 'bmi': 19.0, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 528, 'id': 41800, 'gender': 'Female', 'age': 23.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 79.35, 'bmi': 39.4, 'smoking_status': 'formerly smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 532, 'id': 31564, 'gender': 'Female', 'age': 25.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 90.65, 'bmi': 20.9, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 534, 'id': 71808, 'gender': 'Female', 'age': 20.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 127.18, 'bmi': 31.0, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'élevé'}
# {'Unnamed: 0': 535, 'id': 56998, 'gender': 'Female', 'age': 12.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 138.06, 'bmi': 23.1, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'élevé'}
# {'Unnamed: 0': 538, 'id': 43134, 'gender': 'Female', 'age': 16.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 155.43, 'bmi': 27.3, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'élevé'}
# {'Unnamed: 0': 547, 'id': 20751, 'gender': 'Female', 'age': 26.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 75.29, 'bmi': 22.6, 'smoking_status': 'smokes', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 550, 'id': 68241, 'gender': 'Female', 'age': 15.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 126.96, 'bmi': 28.7, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'élevé'}
# {'Unnamed: 0': 562, 'id': 45238, 'gender': 'Female', 'age': 1.8, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 58.26, 'bmi': 16.5, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 564, 'id': 61511, 'gender': 'Female', 'age': 0.32, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 73.71, 'bmi': 16.2, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 578, 'id': 67744, 'gender': 'Female', 'age': 23.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 74.46, 'bmi': 35.6, 'smoking_status': 'formerly smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 582, 'id': 68245, 'gender': 'Female', 'age': 26.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 59.17, 'bmi': 20.0, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 588, 'id': 15311, 'gender': 'Female', 'age': 24.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 89.99, 'bmi': 24.4, 'smoking_status': 'formerly smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 597, 'id': 40639, 'gender': 'Female', 'age': 1.08, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 60.53, 'bmi': 17.5, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 600, 'id': 8544, 'gender': 'Female', 'age': 24.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Self-employed', 'Residence_type': 'Rural', 'avg_glucose_level': 115.03, 'bmi': 23.4, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 607, 'id': 9906, 'gender': 'Female', 'age': 1.8, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 102.34, 'bmi': 17.0, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'normal'}
# {'Unnamed: 0': 628, 'id': 48144, 'gender': 'Female', 'age': 20.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Govt_job', 'Residence_type': 'Rural', 'avg_glucose_level': 73.0, 'bmi': 20.8, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 640, 'id': 34363, 'gender': 'Female', 'age': 27.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 95.12, 'bmi': 27.0, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 655, 'id': 41927, 'gender': 'Female', 'age': 28.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 64.64, 'bmi': 22.1, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 656, 'id': 54866, 'gender': 'Female', 'age': 9.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 57.27, 'bmi': 28.0, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 657, 'id': 20364, 'gender': 'Female', 'age': 4.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 107.25, 'bmi': 12.0, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'normal'}
# {'Unnamed: 0': 672, 'id': 31145, 'gender': 'Female', 'age': 17.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 67.81, 'bmi': 55.7, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'faible'}
# {'Unnamed: 0': 676, 'id': 57523, 'gender': 'Female', 'age': 26.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 116.38, 'bmi': 21.9, 'smoking_status': 'formerly smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 679, 'id': 68131, 'gender': 'Female', 'age': 27.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 149.95, 'bmi': 25.9, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'élevé'}
# {'Unnamed: 0': 681, 'id': 54182, 'gender': 'Female', 'age': 16.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 74.98, 'bmi': 21.4, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'faible'}
# {'Unnamed: 0': 683, 'id': 15274, 'gender': 'Female', 'age': 2.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 79.89, 'bmi': 31.6, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 684, 'id': 53016, 'gender': 'Female', 'age': 1.8, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 130.61, 'bmi': 14.4, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'élevé'}
# {'Unnamed: 0': 692, 'id': 12593, 'gender': 'Female', 'age': 18.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 80.33, 'bmi': 19.7, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 693, 'id': 51514, 'gender': 'Female', 'age': 13.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 131.51, 'bmi': 41.7, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'élevé'}
# {'Unnamed: 0': 695, 'id': 45796, 'gender': 'Female', 'age': 29.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 91.45, 'bmi': 24.2, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 696, 'id': 31840, 'gender': 'Female', 'age': 12.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 90.58, 'bmi': 19.2, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'normal'}
# {'Unnamed: 0': 704, 'id': 18390, 'gender': 'Female', 'age': 19.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 91.69, 'bmi': 39.5, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 709, 'id': 49086, 'gender': 'Female', 'age': 23.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 60.5, 'bmi': 27.1, 'smoking_status': 'formerly smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 715, 'id': 3590, 'gender': 'Female', 'age': 28.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 80.4, 'bmi': 57.5, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 717, 'id': 40791, 'gender': 'Female', 'age': 13.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 63.26, 'bmi': 19.5, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'faible'}
# {'Unnamed: 0': 718, 'id': 54304, 'gender': 'Female', 'age': 22.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 86.24, 'bmi': 31.2, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 721, 'id': 19234, 'gender': 'Female', 'age': 28.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 84.59, 'bmi': 23.5, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 736, 'id': 41513, 'gender': 'Female', 'age': 20.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 74.02, 'bmi': 22.3, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 740, 'id': 52580, 'gender': 'Female', 'age': 27.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 75.04, 'bmi': 24.5, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 742, 'id': 33723, 'gender': 'Female', 'age': 9.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 95.81, 'bmi': 18.8, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'normal'}
# {'Unnamed: 0': 753, 'id': 49529, 'gender': 'Female', 'age': 1.16, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 60.98, 'bmi': 17.2, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 756, 'id': 49785, 'gender': 'Female', 'age': 18.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 128.97, 'bmi': 23.5, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'élevé'}
# {'Unnamed: 0': 762, 'id': 40055, 'gender': 'Female', 'age': 17.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 173.43, 'bmi': 25.6, 'smoking_status': 'smokes', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'élevé'}
# {'Unnamed: 0': 763, 'id': 18888, 'gender': 'Female', 'age': 20.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 79.08, 'bmi': 41.2, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 790, 'id': 22384, 'gender': 'Female', 'age': 24.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 97.92, 'bmi': 23.1, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 793, 'id': 69427, 'gender': 'Female', 'age': 29.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 101.28, 'bmi': 22.7, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 796, 'id': 64732, 'gender': 'Female', 'age': 29.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 60.26, 'bmi': 20.4, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 797, 'id': 42710, 'gender': 'Female', 'age': 23.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 79.39, 'bmi': 27.6, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 798, 'id': 46683, 'gender': 'Female', 'age': 25.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 122.01, 'bmi': 27.0, 'smoking_status': 'smokes', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 799, 'id': 58909, 'gender': 'Female', 'age': 14.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 78.09, 'bmi': 26.4, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'faible'}
# {'Unnamed: 0': 814, 'id': 10324, 'gender': 'Female', 'age': 5.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 93.88, 'bmi': 14.6, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'normal'}
# {'Unnamed: 0': 820, 'id': 71793, 'gender': 'Female', 'age': 21.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 129.16, 'bmi': 34.4, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'élevé'}
# {'Unnamed: 0': 839, 'id': 2543, 'gender': 'Female', 'age': 19.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 90.42, 'bmi': 21.4, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 840, 'id': 45289, 'gender': 'Female', 'age': 9.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 109.32, 'bmi': 27.4, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'normal'}
# {'Unnamed: 0': 842, 'id': 10792, 'gender': 'Female', 'age': 23.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 79.13, 'bmi': 32.9, 'smoking_status': 'formerly smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 843, 'id': 19153, 'gender': 'Female', 'age': 19.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Self-employed', 'Residence_type': 'Urban', 'avg_glucose_level': 84.06, 'bmi': 24.7, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 850, 'id': 41615, 'gender': 'Female', 'age': 1.4, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 126.18, 'bmi': 18.1, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'élevé'}
# {'Unnamed: 0': 852, 'id': 41537, 'gender': 'Female', 'age': 17.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 62.49, 'bmi': 26.9, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'faible'}
# {'Unnamed: 0': 858, 'id': 16110, 'gender': 'Female', 'age': 19.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 77.19, 'bmi': 37.4, 'smoking_status': 'smokes', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 866, 'id': 70380, 'gender': 'Female', 'age': 20.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 112.96, 'bmi': 27.5, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 872, 'id': 2549, 'gender': 'Female', 'age': 17.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 83.23, 'bmi': 24.3, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'faible'}
# {'Unnamed: 0': 873, 'id': 17245, 'gender': 'Female', 'age': 28.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 87.01, 'bmi': 39.9, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 877, 'id': 10782, 'gender': 'Female', 'age': 3.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 80.63, 'bmi': 15.9, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 886, 'id': 13948, 'gender': 'Female', 'age': 19.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Never_worked', 'Residence_type': 'Urban', 'avg_glucose_level': 86.96, 'bmi': 25.8, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 892, 'id': 65766, 'gender': 'Female', 'age': 27.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 104.33, 'bmi': 20.1, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 893, 'id': 42482, 'gender': 'Female', 'age': 4.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 62.61, 'bmi': 21.2, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 904, 'id': 56089, 'gender': 'Female', 'age': 25.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 63.64, 'bmi': 31.3, 'smoking_status': 'formerly smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 912, 'id': 11745, 'gender': 'Female', 'age': 29.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 65.36, 'bmi': 28.8, 'smoking_status': 'formerly smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 913, 'id': 17733, 'gender': 'Female', 'age': 1.72, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 109.51, 'bmi': 19.5, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'normal'}
# {'Unnamed: 0': 920, 'id': 22952, 'gender': 'Female', 'age': 21.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Govt_job', 'Residence_type': 'Urban', 'avg_glucose_level': 111.61, 'bmi': 36.9, 'smoking_status': 'smokes', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 921, 'id': 32554, 'gender': 'Female', 'age': 16.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 109.02, 'bmi': 19.8, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'normal'}
# {'Unnamed: 0': 922, 'id': 45893, 'gender': 'Female', 'age': 8.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 106.51, 'bmi': 12.3, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'normal'}
# {'Unnamed: 0': 925, 'id': 53538, 'gender': 'Female', 'age': 7.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 61.68, 'bmi': 16.4, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 928, 'id': 41097, 'gender': 'Female', 'age': 23.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 70.03, 'bmi': 78.0, 'smoking_status': 'smokes', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 932, 'id': 42108, 'gender': 'Female', 'age': 24.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Govt_job', 'Residence_type': 'Rural', 'avg_glucose_level': 100.97, 'bmi': 27.9, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 936, 'id': 224, 'gender': 'Female', 'age': 23.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 110.16, 'bmi': 27.6, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 938, 'id': 27146, 'gender': 'Female', 'age': 23.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 92.87, 'bmi': 30.1, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 952, 'id': 30605, 'gender': 'Female', 'age': 20.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 76.34, 'bmi': 20.6, 'smoking_status': 'smokes', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 956, 'id': 2879, 'gender': 'Female', 'age': 15.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Self-employed', 'Residence_type': 'Urban', 'avg_glucose_level': 90.1, 'bmi': 32.1, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'normal'}
# {'Unnamed: 0': 957, 'id': 59684, 'gender': 'Female', 'age': 3.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 65.15, 'bmi': 15.1, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 961, 'id': 16402, 'gender': 'Female', 'age': 5.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 93.07, 'bmi': 19.1, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'normal'}
# {'Unnamed: 0': 966, 'id': 48843, 'gender': 'Female', 'age': 27.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 58.39, 'bmi': 30.4, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 969, 'id': 44481, 'gender': 'Female', 'age': 19.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 72.84, 'bmi': 22.7, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 972, 'id': 19101, 'gender': 'Female', 'age': 16.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 87.98, 'bmi': 22.4, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'faible'}
# {'Unnamed: 0': 974, 'id': 11973, 'gender': 'Female', 'age': 10.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 124.6, 'bmi': 18.6, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'normal'}
# {'Unnamed: 0': 977, 'id': 59178, 'gender': 'Female', 'age': 7.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 86.75, 'bmi': 22.3, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 980, 'id': 55599, 'gender': 'Female', 'age': 9.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 69.87, 'bmi': 18.0, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 985, 'id': 46385, 'gender': 'Female', 'age': 21.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 59.15, 'bmi': 22.6, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 986, 'id': 46323, 'gender': 'Female', 'age': 2.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 165.11, 'bmi': 18.0, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'élevé'}
# {'Unnamed: 0': 998, 'id': 37830, 'gender': 'Female', 'age': 29.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 73.67, 'bmi': 21.0, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 1005, 'id': 3437, 'gender': 'Female', 'age': 26.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 82.61, 'bmi': 28.5, 'smoking_status': 'smokes', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 1006, 'id': 6355, 'gender': 'Female', 'age': 6.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 72.07, 'bmi': 19.5, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 1012, 'id': 72779, 'gender': 'Female', 'age': 14.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 131.77, 'bmi': 31.0, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'élevé'}
# {'Unnamed: 0': 1020, 'id': 12396, 'gender': 'Female', 'age': 20.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 100.81, 'bmi': 26.8, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 1032, 'id': 69622, 'gender': 'Female', 'age': 8.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 65.32, 'bmi': 18.4, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 1039, 'id': 34281, 'gender': 'Female', 'age': 15.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 95.43, 'bmi': 25.0, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'normal'}
# {'Unnamed: 0': 1040, 'id': 7990, 'gender': 'Female', 'age': 24.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 84.08, 'bmi': 24.5, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 1045, 'id': 11691, 'gender': 'Female', 'age': 19.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 75.08, 'bmi': 21.7, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 1047, 'id': 13319, 'gender': 'Female', 'age': 5.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 84.93, 'bmi': 17.6, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 1060, 'id': 6965, 'gender': 'Female', 'age': 19.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 96.02, 'bmi': 21.9, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# ...
# {'Unnamed: 0': 4844, 'id': 25942, 'gender': 'Female', 'age': 4.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 72.49, 'bmi': 16.9, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 4848, 'id': 15593, 'gender': 'Female', 'age': 7.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 128.17, 'bmi': 18.9, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'élevé'}
# {'Unnamed: 0': 4853, 'id': 62656, 'gender': 'Female', 'age': 14.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 101.6, 'bmi': 25.3, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'normal'}
# {'Unnamed: 0': 4856, 'id': 31254, 'gender': 'Female', 'age': 20.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 96.69, 'bmi': 24.6, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 4860, 'id': 70396, 'gender': 'Female', 'age': 1.08, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 109.33, 'bmi': 18.2, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'normal'}
# {'Unnamed: 0': 4863, 'id': 68601, 'gender': 'Female', 'age': 18.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 67.92, 'bmi': 19.4, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 4864, 'id': 13236, 'gender': 'Female', 'age': 13.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 73.48, 'bmi': 22.9, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'faible'}
# {'Unnamed: 0': 4870, 'id': 59847, 'gender': 'Female', 'age': 12.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 114.34, 'bmi': 23.6, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'normal'}
# {'Unnamed: 0': 4872, 'id': 13583, 'gender': 'Female', 'age': 5.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 88.44, 'bmi': 18.0, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 4886, 'id': 60562, 'gender': 'Female', 'age': 21.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 55.12, 'bmi': 21.8, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 4887, 'id': 22013, 'gender': 'Female', 'age': 17.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 105.91, 'bmi': 30.8, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'normal'}
# {'Unnamed: 0': 4889, 'id': 6517, 'gender': 'Female', 'age': 24.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Govt_job', 'Residence_type': 'Urban', 'avg_glucose_level': 83.1, 'bmi': 42.5, 'smoking_status': 'smokes', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 4891, 'id': 18636, 'gender': 'Female', 'age': 26.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Govt_job', 'Residence_type': 'Urban', 'avg_glucose_level': 72.56, 'bmi': 35.4, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 4898, 'id': 54795, 'gender': 'Female', 'age': 12.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 132.85, 'bmi': 16.2, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'élevé'}
# {'Unnamed: 0': 4903, 'id': 56629, 'gender': 'Female', 'age': 14.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 83.56, 'bmi': 33.1, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'faible'}
# {'Unnamed: 0': 4904, 'id': 22417, 'gender': 'Female', 'age': 5.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 80.93, 'bmi': 24.8, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 4910, 'id': 37622, 'gender': 'Female', 'age': 0.32, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 108.63, 'bmi': 19.6, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'normal'}
# {'Unnamed: 0': 4923, 'id': 72186, 'gender': 'Female', 'age': 15.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 82.19, 'bmi': 40.5, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'faible'}
# {'Unnamed: 0': 4927, 'id': 25391, 'gender': 'Female', 'age': 10.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 69.84, 'bmi': 13.7, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 4940, 'id': 68596, 'gender': 'Female', 'age': 19.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 58.39, 'bmi': 28.2, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 4943, 'id': 54067, 'gender': 'Female', 'age': 26.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 67.21, 'bmi': 21.8, 'smoking_status': 'formerly smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 4950, 'id': 66650, 'gender': 'Female', 'age': 17.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 68.86, 'bmi': 41.1, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'faible'}
# {'Unnamed: 0': 4951, 'id': 59945, 'gender': 'Female', 'age': 23.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 132.88, 'bmi': 24.9, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'élevé'}
# {'Unnamed: 0': 4961, 'id': 3720, 'gender': 'Female', 'age': 2.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 80.3, 'bmi': 21.2, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 4964, 'id': 58209, 'gender': 'Female', 'age': 22.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 140.14, 'bmi': 21.1, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'élevé'}
# {'Unnamed: 0': 4965, 'id': 20634, 'gender': 'Female', 'age': 11.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 92.65, 'bmi': 15.7, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'normal'}
# {'Unnamed: 0': 4976, 'id': 63656, 'gender': 'Female', 'age': 18.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 101.95, 'bmi': 46.0, 'smoking_status': 'formerly smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 4978, 'id': 22591, 'gender': 'Female', 'age': 4.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 99.76, 'bmi': 23.2, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'normal'}
# {'Unnamed: 0': 4980, 'id': 19601, 'gender': 'Female', 'age': 19.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 100.6, 'bmi': 20.5, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 4989, 'id': 25860, 'gender': 'Female', 'age': 11.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 123.04, 'bmi': 15.9, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'normal'}
# {'Unnamed: 0': 4997, 'id': 11145, 'gender': 'Female', 'age': 8.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 104.03, 'bmi': 18.4, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'normal'}
# {'Unnamed: 0': 4998, 'id': 39229, 'gender': 'Female', 'age': 24.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 67.99, 'bmi': 32.1, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 5004, 'id': 27435, 'gender': 'Female', 'age': 17.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 82.64, 'bmi': 31.1, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'faible'}
# {'Unnamed: 0': 5005, 'id': 10829, 'gender': 'Female', 'age': 21.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 71.34, 'bmi': 24.0, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 5027, 'id': 62416, 'gender': 'Female', 'age': 26.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 73.29, 'bmi': 27.8, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 5031, 'id': 67465, 'gender': 'Female', 'age': 20.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 117.59, 'bmi': 17.1, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 5032, 'id': 67426, 'gender': 'Female', 'age': 1.24, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 61.94, 'bmi': 20.3, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 5033, 'id': 19508, 'gender': 'Female', 'age': 26.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 116.68, 'bmi': 18.7, 'smoking_status': 'formerly smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 5052, 'id': 31836, 'gender': 'Female', 'age': 6.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 91.05, 'bmi': 22.1, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'normal'}
# {'Unnamed: 0': 5055, 'id': 11630, 'gender': 'Female', 'age': 25.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 92.06, 'bmi': 25.3, 'smoking_status': 'smokes', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 5069, 'id': 15599, 'gender': 'Female', 'age': 21.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 91.01, 'bmi': 28.7, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 5070, 'id': 62425, 'gender': 'Female', 'age': 5.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 61.98, 'bmi': 16.8, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 5073, 'id': 17231, 'gender': 'Female', 'age': 24.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 90.42, 'bmi': 24.3, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 5078, 'id': 27446, 'gender': 'Female', 'age': 8.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 76.31, 'bmi': 15.5, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 5080, 'id': 22691, 'gender': 'Female', 'age': 29.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Self-employed', 'Residence_type': 'Urban', 'avg_glucose_level': 90.52, 'bmi': 28.0, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 5083, 'id': 72914, 'gender': 'Female', 'age': 19.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 90.57, 'bmi': 24.2, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 5089, 'id': 56714, 'gender': 'Female', 'age': 0.72, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 62.13, 'bmi': 16.8, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 5103, 'id': 22127, 'gender': 'Female', 'age': 18.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 82.85, 'bmi': 46.9, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 5104, 'id': 14180, 'gender': 'Female', 'age': 13.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 103.08, 'bmi': 18.6, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'normal'}

# %%
# fonction filter_patient paramètre max_age optionnel
def filter_patients(df: pd.DataFrame, gender: str, stroke: int, max_age: float = None) -> list[dict]:
   
    filtered_df = df[
        (df['stroke'] == stroke) &
        (df['gender'] == gender) 
        
        
    ]
    
    if max_age is not None:
        filtered_df = filtered_df[filtered_df['age'] <= max_age]

    return filtered_df.to_dict(orient='records')
print("Patients filtrés :")
for patient in patients:
    print(patient)
# Out:
# Patients filtrés :
# {'Unnamed: 0': 251, 'id': 16523, 'gender': 'Female', 'age': 8.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 110.89, 'bmi': 17.6, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'normal'}
# {'Unnamed: 0': 265, 'id': 19584, 'gender': 'Female', 'age': 20.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 84.62, 'bmi': 19.7, 'smoking_status': 'smokes', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 274, 'id': 70336, 'gender': 'Female', 'age': 25.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 60.84, 'bmi': 24.5, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 282, 'id': 33759, 'gender': 'Female', 'age': 3.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 73.74, 'bmi': 16.0, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 286, 'id': 36811, 'gender': 'Female', 'age': 23.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 94.09, 'bmi': 30.9, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 288, 'id': 70970, 'gender': 'Female', 'age': 17.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Self-employed', 'Residence_type': 'Urban', 'avg_glucose_level': 82.18, 'bmi': 23.4, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'faible'}
# {'Unnamed: 0': 292, 'id': 44338, 'gender': 'Female', 'age': 16.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 110.63, 'bmi': 19.5, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'normal'}
# {'Unnamed: 0': 294, 'id': 34974, 'gender': 'Female', 'age': 22.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 79.81, 'bmi': 27.7, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 306, 'id': 16371, 'gender': 'Female', 'age': 13.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 75.42, 'bmi': 40.1, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'faible'}
# {'Unnamed: 0': 312, 'id': 68249, 'gender': 'Female', 'age': 27.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 85.6, 'bmi': 21.4, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 319, 'id': 1686, 'gender': 'Female', 'age': 29.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 71.89, 'bmi': 27.6, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 322, 'id': 21956, 'gender': 'Female', 'age': 22.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 69.94, 'bmi': 22.8, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 328, 'id': 29865, 'gender': 'Female', 'age': 21.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 89.44, 'bmi': 21.9, 'smoking_status': 'smokes', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 329, 'id': 54918, 'gender': 'Female', 'age': 18.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 111.38, 'bmi': 38.4, 'smoking_status': 'smokes', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 340, 'id': 10449, 'gender': 'Female', 'age': 24.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 75.23, 'bmi': 29.0, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 345, 'id': 9487, 'gender': 'Female', 'age': 23.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 99.92, 'bmi': 25.8, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 348, 'id': 28102, 'gender': 'Female', 'age': 25.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 66.3, 'bmi': 27.2, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 352, 'id': 40670, 'gender': 'Female', 'age': 20.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 96.57, 'bmi': 34.1, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 359, 'id': 46785, 'gender': 'Female', 'age': 29.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 63.69, 'bmi': 28.1, 'smoking_status': 'smokes', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 363, 'id': 7559, 'gender': 'Female', 'age': 0.64, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 83.82, 'bmi': 24.9, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 369, 'id': 8171, 'gender': 'Female', 'age': 4.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 93.25, 'bmi': 16.6, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'normal'}
# {'Unnamed: 0': 371, 'id': 43232, 'gender': 'Female', 'age': 18.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 80.05, 'bmi': 24.2, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 373, 'id': 34402, 'gender': 'Female', 'age': 23.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 91.97, 'bmi': 21.6, 'smoking_status': 'formerly smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 376, 'id': 22706, 'gender': 'Female', 'age': 0.88, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 88.11, 'bmi': 15.5, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 378, 'id': 28637, 'gender': 'Female', 'age': 14.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 72.36, 'bmi': 20.5, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'faible'}
# {'Unnamed: 0': 394, 'id': 5708, 'gender': 'Female', 'age': 20.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 91.6, 'bmi': 28.1, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 395, 'id': 23462, 'gender': 'Female', 'age': 17.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 87.52, 'bmi': 39.2, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'faible'}
# {'Unnamed: 0': 400, 'id': 65357, 'gender': 'Female', 'age': 5.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 84.59, 'bmi': 17.7, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 401, 'id': 49465, 'gender': 'Female', 'age': 13.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 70.16, 'bmi': 21.2, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'faible'}
# {'Unnamed: 0': 402, 'id': 31143, 'gender': 'Female', 'age': 22.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 107.52, 'bmi': 41.6, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 407, 'id': 36007, 'gender': 'Female', 'age': 21.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 101.37, 'bmi': 37.9, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 408, 'id': 14123, 'gender': 'Female', 'age': 22.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 105.22, 'bmi': 31.1, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 416, 'id': 27029, 'gender': 'Female', 'age': 3.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 73.2, 'bmi': 16.8, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 418, 'id': 45719, 'gender': 'Female', 'age': 22.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 82.0, 'bmi': 26.4, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 419, 'id': 129, 'gender': 'Female', 'age': 24.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 97.55, 'bmi': 26.2, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 421, 'id': 530, 'gender': 'Female', 'age': 12.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 75.22, 'bmi': 20.9, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 425, 'id': 6107, 'gender': 'Female', 'age': 5.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 77.88, 'bmi': 13.8, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 437, 'id': 5010, 'gender': 'Female', 'age': 2.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 92.48, 'bmi': 18.0, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'normal'}
# {'Unnamed: 0': 440, 'id': 56681, 'gender': 'Female', 'age': 22.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 130.34, 'bmi': 22.0, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'élevé'}
# {'Unnamed: 0': 441, 'id': 56716, 'gender': 'Female', 'age': 26.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 82.59, 'bmi': 29.4, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 459, 'id': 48272, 'gender': 'Female', 'age': 11.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 87.51, 'bmi': 24.4, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 460, 'id': 2893, 'gender': 'Female', 'age': 7.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 72.35, 'bmi': 17.0, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 461, 'id': 34376, 'gender': 'Female', 'age': 16.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 113.47, 'bmi': 19.5, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'normal'}
# {'Unnamed: 0': 471, 'id': 69687, 'gender': 'Female', 'age': 18.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Self-employed', 'Residence_type': 'Rural', 'avg_glucose_level': 93.88, 'bmi': 22.2, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 493, 'id': 66570, 'gender': 'Female', 'age': 23.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 69.24, 'bmi': 51.0, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 497, 'id': 37832, 'gender': 'Female', 'age': 14.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 129.53, 'bmi': 21.3, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'élevé'}
# {'Unnamed: 0': 498, 'id': 21058, 'gender': 'Female', 'age': 15.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 114.53, 'bmi': 29.1, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'normal'}
# {'Unnamed: 0': 515, 'id': 67733, 'gender': 'Female', 'age': 28.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 183.45, 'bmi': 40.5, 'smoking_status': 'smokes', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'élevé'}
# {'Unnamed: 0': 525, 'id': 29933, 'gender': 'Female', 'age': 5.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 86.11, 'bmi': 19.0, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 528, 'id': 41800, 'gender': 'Female', 'age': 23.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 79.35, 'bmi': 39.4, 'smoking_status': 'formerly smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 532, 'id': 31564, 'gender': 'Female', 'age': 25.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 90.65, 'bmi': 20.9, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 534, 'id': 71808, 'gender': 'Female', 'age': 20.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 127.18, 'bmi': 31.0, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'élevé'}
# {'Unnamed: 0': 535, 'id': 56998, 'gender': 'Female', 'age': 12.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 138.06, 'bmi': 23.1, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'élevé'}
# {'Unnamed: 0': 538, 'id': 43134, 'gender': 'Female', 'age': 16.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 155.43, 'bmi': 27.3, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'élevé'}
# {'Unnamed: 0': 547, 'id': 20751, 'gender': 'Female', 'age': 26.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 75.29, 'bmi': 22.6, 'smoking_status': 'smokes', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 550, 'id': 68241, 'gender': 'Female', 'age': 15.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 126.96, 'bmi': 28.7, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'élevé'}
# {'Unnamed: 0': 562, 'id': 45238, 'gender': 'Female', 'age': 1.8, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 58.26, 'bmi': 16.5, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 564, 'id': 61511, 'gender': 'Female', 'age': 0.32, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 73.71, 'bmi': 16.2, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 578, 'id': 67744, 'gender': 'Female', 'age': 23.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 74.46, 'bmi': 35.6, 'smoking_status': 'formerly smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 582, 'id': 68245, 'gender': 'Female', 'age': 26.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 59.17, 'bmi': 20.0, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 588, 'id': 15311, 'gender': 'Female', 'age': 24.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 89.99, 'bmi': 24.4, 'smoking_status': 'formerly smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 597, 'id': 40639, 'gender': 'Female', 'age': 1.08, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 60.53, 'bmi': 17.5, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 600, 'id': 8544, 'gender': 'Female', 'age': 24.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Self-employed', 'Residence_type': 'Rural', 'avg_glucose_level': 115.03, 'bmi': 23.4, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 607, 'id': 9906, 'gender': 'Female', 'age': 1.8, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 102.34, 'bmi': 17.0, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'normal'}
# {'Unnamed: 0': 628, 'id': 48144, 'gender': 'Female', 'age': 20.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Govt_job', 'Residence_type': 'Rural', 'avg_glucose_level': 73.0, 'bmi': 20.8, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 640, 'id': 34363, 'gender': 'Female', 'age': 27.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 95.12, 'bmi': 27.0, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 655, 'id': 41927, 'gender': 'Female', 'age': 28.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 64.64, 'bmi': 22.1, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 656, 'id': 54866, 'gender': 'Female', 'age': 9.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 57.27, 'bmi': 28.0, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 657, 'id': 20364, 'gender': 'Female', 'age': 4.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 107.25, 'bmi': 12.0, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'normal'}
# {'Unnamed: 0': 672, 'id': 31145, 'gender': 'Female', 'age': 17.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 67.81, 'bmi': 55.7, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'faible'}
# {'Unnamed: 0': 676, 'id': 57523, 'gender': 'Female', 'age': 26.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 116.38, 'bmi': 21.9, 'smoking_status': 'formerly smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 679, 'id': 68131, 'gender': 'Female', 'age': 27.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 149.95, 'bmi': 25.9, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'élevé'}
# {'Unnamed: 0': 681, 'id': 54182, 'gender': 'Female', 'age': 16.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 74.98, 'bmi': 21.4, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'faible'}
# {'Unnamed: 0': 683, 'id': 15274, 'gender': 'Female', 'age': 2.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 79.89, 'bmi': 31.6, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 684, 'id': 53016, 'gender': 'Female', 'age': 1.8, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 130.61, 'bmi': 14.4, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'élevé'}
# {'Unnamed: 0': 692, 'id': 12593, 'gender': 'Female', 'age': 18.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 80.33, 'bmi': 19.7, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 693, 'id': 51514, 'gender': 'Female', 'age': 13.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 131.51, 'bmi': 41.7, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'élevé'}
# {'Unnamed: 0': 695, 'id': 45796, 'gender': 'Female', 'age': 29.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 91.45, 'bmi': 24.2, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 696, 'id': 31840, 'gender': 'Female', 'age': 12.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 90.58, 'bmi': 19.2, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'normal'}
# {'Unnamed: 0': 704, 'id': 18390, 'gender': 'Female', 'age': 19.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 91.69, 'bmi': 39.5, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 709, 'id': 49086, 'gender': 'Female', 'age': 23.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 60.5, 'bmi': 27.1, 'smoking_status': 'formerly smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 715, 'id': 3590, 'gender': 'Female', 'age': 28.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 80.4, 'bmi': 57.5, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 717, 'id': 40791, 'gender': 'Female', 'age': 13.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 63.26, 'bmi': 19.5, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'faible'}
# {'Unnamed: 0': 718, 'id': 54304, 'gender': 'Female', 'age': 22.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 86.24, 'bmi': 31.2, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 721, 'id': 19234, 'gender': 'Female', 'age': 28.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 84.59, 'bmi': 23.5, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 736, 'id': 41513, 'gender': 'Female', 'age': 20.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 74.02, 'bmi': 22.3, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 740, 'id': 52580, 'gender': 'Female', 'age': 27.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 75.04, 'bmi': 24.5, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 742, 'id': 33723, 'gender': 'Female', 'age': 9.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 95.81, 'bmi': 18.8, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'normal'}
# {'Unnamed: 0': 753, 'id': 49529, 'gender': 'Female', 'age': 1.16, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 60.98, 'bmi': 17.2, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 756, 'id': 49785, 'gender': 'Female', 'age': 18.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 128.97, 'bmi': 23.5, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'élevé'}
# {'Unnamed: 0': 762, 'id': 40055, 'gender': 'Female', 'age': 17.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 173.43, 'bmi': 25.6, 'smoking_status': 'smokes', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'élevé'}
# {'Unnamed: 0': 763, 'id': 18888, 'gender': 'Female', 'age': 20.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 79.08, 'bmi': 41.2, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 790, 'id': 22384, 'gender': 'Female', 'age': 24.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 97.92, 'bmi': 23.1, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 793, 'id': 69427, 'gender': 'Female', 'age': 29.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 101.28, 'bmi': 22.7, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 796, 'id': 64732, 'gender': 'Female', 'age': 29.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 60.26, 'bmi': 20.4, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 797, 'id': 42710, 'gender': 'Female', 'age': 23.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 79.39, 'bmi': 27.6, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 798, 'id': 46683, 'gender': 'Female', 'age': 25.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 122.01, 'bmi': 27.0, 'smoking_status': 'smokes', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 799, 'id': 58909, 'gender': 'Female', 'age': 14.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 78.09, 'bmi': 26.4, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'faible'}
# {'Unnamed: 0': 814, 'id': 10324, 'gender': 'Female', 'age': 5.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 93.88, 'bmi': 14.6, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'normal'}
# {'Unnamed: 0': 820, 'id': 71793, 'gender': 'Female', 'age': 21.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 129.16, 'bmi': 34.4, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'élevé'}
# {'Unnamed: 0': 839, 'id': 2543, 'gender': 'Female', 'age': 19.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 90.42, 'bmi': 21.4, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 840, 'id': 45289, 'gender': 'Female', 'age': 9.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 109.32, 'bmi': 27.4, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'normal'}
# {'Unnamed: 0': 842, 'id': 10792, 'gender': 'Female', 'age': 23.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 79.13, 'bmi': 32.9, 'smoking_status': 'formerly smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 843, 'id': 19153, 'gender': 'Female', 'age': 19.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Self-employed', 'Residence_type': 'Urban', 'avg_glucose_level': 84.06, 'bmi': 24.7, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 850, 'id': 41615, 'gender': 'Female', 'age': 1.4, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 126.18, 'bmi': 18.1, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'élevé'}
# {'Unnamed: 0': 852, 'id': 41537, 'gender': 'Female', 'age': 17.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 62.49, 'bmi': 26.9, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'faible'}
# {'Unnamed: 0': 858, 'id': 16110, 'gender': 'Female', 'age': 19.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 77.19, 'bmi': 37.4, 'smoking_status': 'smokes', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 866, 'id': 70380, 'gender': 'Female', 'age': 20.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 112.96, 'bmi': 27.5, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 872, 'id': 2549, 'gender': 'Female', 'age': 17.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 83.23, 'bmi': 24.3, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'faible'}
# {'Unnamed: 0': 873, 'id': 17245, 'gender': 'Female', 'age': 28.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 87.01, 'bmi': 39.9, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 877, 'id': 10782, 'gender': 'Female', 'age': 3.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 80.63, 'bmi': 15.9, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 886, 'id': 13948, 'gender': 'Female', 'age': 19.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Never_worked', 'Residence_type': 'Urban', 'avg_glucose_level': 86.96, 'bmi': 25.8, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 892, 'id': 65766, 'gender': 'Female', 'age': 27.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 104.33, 'bmi': 20.1, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 893, 'id': 42482, 'gender': 'Female', 'age': 4.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 62.61, 'bmi': 21.2, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 904, 'id': 56089, 'gender': 'Female', 'age': 25.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 63.64, 'bmi': 31.3, 'smoking_status': 'formerly smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 912, 'id': 11745, 'gender': 'Female', 'age': 29.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 65.36, 'bmi': 28.8, 'smoking_status': 'formerly smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 913, 'id': 17733, 'gender': 'Female', 'age': 1.72, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 109.51, 'bmi': 19.5, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'normal'}
# {'Unnamed: 0': 920, 'id': 22952, 'gender': 'Female', 'age': 21.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Govt_job', 'Residence_type': 'Urban', 'avg_glucose_level': 111.61, 'bmi': 36.9, 'smoking_status': 'smokes', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 921, 'id': 32554, 'gender': 'Female', 'age': 16.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 109.02, 'bmi': 19.8, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'normal'}
# {'Unnamed: 0': 922, 'id': 45893, 'gender': 'Female', 'age': 8.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 106.51, 'bmi': 12.3, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'normal'}
# {'Unnamed: 0': 925, 'id': 53538, 'gender': 'Female', 'age': 7.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 61.68, 'bmi': 16.4, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 928, 'id': 41097, 'gender': 'Female', 'age': 23.0, 'hypertension': 1, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 70.03, 'bmi': 78.0, 'smoking_status': 'smokes', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 932, 'id': 42108, 'gender': 'Female', 'age': 24.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Govt_job', 'Residence_type': 'Rural', 'avg_glucose_level': 100.97, 'bmi': 27.9, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 936, 'id': 224, 'gender': 'Female', 'age': 23.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 110.16, 'bmi': 27.6, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 938, 'id': 27146, 'gender': 'Female', 'age': 23.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 92.87, 'bmi': 30.1, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 952, 'id': 30605, 'gender': 'Female', 'age': 20.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 76.34, 'bmi': 20.6, 'smoking_status': 'smokes', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 956, 'id': 2879, 'gender': 'Female', 'age': 15.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Self-employed', 'Residence_type': 'Urban', 'avg_glucose_level': 90.1, 'bmi': 32.1, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'normal'}
# {'Unnamed: 0': 957, 'id': 59684, 'gender': 'Female', 'age': 3.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 65.15, 'bmi': 15.1, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 961, 'id': 16402, 'gender': 'Female', 'age': 5.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 93.07, 'bmi': 19.1, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'normal'}
# {'Unnamed: 0': 966, 'id': 48843, 'gender': 'Female', 'age': 27.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 58.39, 'bmi': 30.4, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 969, 'id': 44481, 'gender': 'Female', 'age': 19.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 72.84, 'bmi': 22.7, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 972, 'id': 19101, 'gender': 'Female', 'age': 16.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 87.98, 'bmi': 22.4, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'faible'}
# {'Unnamed: 0': 974, 'id': 11973, 'gender': 'Female', 'age': 10.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 124.6, 'bmi': 18.6, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'normal'}
# {'Unnamed: 0': 977, 'id': 59178, 'gender': 'Female', 'age': 7.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 86.75, 'bmi': 22.3, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 980, 'id': 55599, 'gender': 'Female', 'age': 9.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 69.87, 'bmi': 18.0, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 985, 'id': 46385, 'gender': 'Female', 'age': 21.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 59.15, 'bmi': 22.6, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 986, 'id': 46323, 'gender': 'Female', 'age': 2.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 165.11, 'bmi': 18.0, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'élevé'}
# {'Unnamed: 0': 998, 'id': 37830, 'gender': 'Female', 'age': 29.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 73.67, 'bmi': 21.0, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 1005, 'id': 3437, 'gender': 'Female', 'age': 26.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 82.61, 'bmi': 28.5, 'smoking_status': 'smokes', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 1006, 'id': 6355, 'gender': 'Female', 'age': 6.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 72.07, 'bmi': 19.5, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 1012, 'id': 72779, 'gender': 'Female', 'age': 14.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 131.77, 'bmi': 31.0, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'élevé'}
# {'Unnamed: 0': 1020, 'id': 12396, 'gender': 'Female', 'age': 20.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 100.81, 'bmi': 26.8, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 1032, 'id': 69622, 'gender': 'Female', 'age': 8.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 65.32, 'bmi': 18.4, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 1039, 'id': 34281, 'gender': 'Female', 'age': 15.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 95.43, 'bmi': 25.0, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'normal'}
# {'Unnamed: 0': 1040, 'id': 7990, 'gender': 'Female', 'age': 24.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 84.08, 'bmi': 24.5, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 1045, 'id': 11691, 'gender': 'Female', 'age': 19.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 75.08, 'bmi': 21.7, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 1047, 'id': 13319, 'gender': 'Female', 'age': 5.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 84.93, 'bmi': 17.6, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 1060, 'id': 6965, 'gender': 'Female', 'age': 19.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 96.02, 'bmi': 21.9, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# ...
# {'Unnamed: 0': 4844, 'id': 25942, 'gender': 'Female', 'age': 4.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 72.49, 'bmi': 16.9, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 4848, 'id': 15593, 'gender': 'Female', 'age': 7.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 128.17, 'bmi': 18.9, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'élevé'}
# {'Unnamed: 0': 4853, 'id': 62656, 'gender': 'Female', 'age': 14.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 101.6, 'bmi': 25.3, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'normal'}
# {'Unnamed: 0': 4856, 'id': 31254, 'gender': 'Female', 'age': 20.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 96.69, 'bmi': 24.6, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 4860, 'id': 70396, 'gender': 'Female', 'age': 1.08, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 109.33, 'bmi': 18.2, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'normal'}
# {'Unnamed: 0': 4863, 'id': 68601, 'gender': 'Female', 'age': 18.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 67.92, 'bmi': 19.4, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 4864, 'id': 13236, 'gender': 'Female', 'age': 13.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 73.48, 'bmi': 22.9, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'faible'}
# {'Unnamed: 0': 4870, 'id': 59847, 'gender': 'Female', 'age': 12.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 114.34, 'bmi': 23.6, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'normal'}
# {'Unnamed: 0': 4872, 'id': 13583, 'gender': 'Female', 'age': 5.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 88.44, 'bmi': 18.0, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 4886, 'id': 60562, 'gender': 'Female', 'age': 21.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 55.12, 'bmi': 21.8, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 4887, 'id': 22013, 'gender': 'Female', 'age': 17.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 105.91, 'bmi': 30.8, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'normal'}
# {'Unnamed: 0': 4889, 'id': 6517, 'gender': 'Female', 'age': 24.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Govt_job', 'Residence_type': 'Urban', 'avg_glucose_level': 83.1, 'bmi': 42.5, 'smoking_status': 'smokes', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 4891, 'id': 18636, 'gender': 'Female', 'age': 26.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Govt_job', 'Residence_type': 'Urban', 'avg_glucose_level': 72.56, 'bmi': 35.4, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 4898, 'id': 54795, 'gender': 'Female', 'age': 12.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 132.85, 'bmi': 16.2, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'élevé'}
# {'Unnamed: 0': 4903, 'id': 56629, 'gender': 'Female', 'age': 14.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 83.56, 'bmi': 33.1, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'faible'}
# {'Unnamed: 0': 4904, 'id': 22417, 'gender': 'Female', 'age': 5.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 80.93, 'bmi': 24.8, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 4910, 'id': 37622, 'gender': 'Female', 'age': 0.32, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 108.63, 'bmi': 19.6, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'normal'}
# {'Unnamed: 0': 4923, 'id': 72186, 'gender': 'Female', 'age': 15.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 82.19, 'bmi': 40.5, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'faible'}
# {'Unnamed: 0': 4927, 'id': 25391, 'gender': 'Female', 'age': 10.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 69.84, 'bmi': 13.7, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 4940, 'id': 68596, 'gender': 'Female', 'age': 19.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 58.39, 'bmi': 28.2, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 4943, 'id': 54067, 'gender': 'Female', 'age': 26.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 67.21, 'bmi': 21.8, 'smoking_status': 'formerly smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 4950, 'id': 66650, 'gender': 'Female', 'age': 17.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 68.86, 'bmi': 41.1, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'faible'}
# {'Unnamed: 0': 4951, 'id': 59945, 'gender': 'Female', 'age': 23.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 132.88, 'bmi': 24.9, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'élevé'}
# {'Unnamed: 0': 4961, 'id': 3720, 'gender': 'Female', 'age': 2.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 80.3, 'bmi': 21.2, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 4964, 'id': 58209, 'gender': 'Female', 'age': 22.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 140.14, 'bmi': 21.1, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'élevé'}
# {'Unnamed: 0': 4965, 'id': 20634, 'gender': 'Female', 'age': 11.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 92.65, 'bmi': 15.7, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'normal'}
# {'Unnamed: 0': 4976, 'id': 63656, 'gender': 'Female', 'age': 18.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 101.95, 'bmi': 46.0, 'smoking_status': 'formerly smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 4978, 'id': 22591, 'gender': 'Female', 'age': 4.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 99.76, 'bmi': 23.2, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'normal'}
# {'Unnamed: 0': 4980, 'id': 19601, 'gender': 'Female', 'age': 19.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 100.6, 'bmi': 20.5, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 4989, 'id': 25860, 'gender': 'Female', 'age': 11.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 123.04, 'bmi': 15.9, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'normal'}
# {'Unnamed: 0': 4997, 'id': 11145, 'gender': 'Female', 'age': 8.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 104.03, 'bmi': 18.4, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'normal'}
# {'Unnamed: 0': 4998, 'id': 39229, 'gender': 'Female', 'age': 24.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 67.99, 'bmi': 32.1, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 5004, 'id': 27435, 'gender': 'Female', 'age': 17.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 82.64, 'bmi': 31.1, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'faible'}
# {'Unnamed: 0': 5005, 'id': 10829, 'gender': 'Female', 'age': 21.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 71.34, 'bmi': 24.0, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 5027, 'id': 62416, 'gender': 'Female', 'age': 26.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 73.29, 'bmi': 27.8, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 5031, 'id': 67465, 'gender': 'Female', 'age': 20.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 117.59, 'bmi': 17.1, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 5032, 'id': 67426, 'gender': 'Female', 'age': 1.24, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 61.94, 'bmi': 20.3, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 5033, 'id': 19508, 'gender': 'Female', 'age': 26.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 116.68, 'bmi': 18.7, 'smoking_status': 'formerly smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 5052, 'id': 31836, 'gender': 'Female', 'age': 6.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 91.05, 'bmi': 22.1, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'normal'}
# {'Unnamed: 0': 5055, 'id': 11630, 'gender': 'Female', 'age': 25.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 92.06, 'bmi': 25.3, 'smoking_status': 'smokes', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 5069, 'id': 15599, 'gender': 'Female', 'age': 21.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 91.01, 'bmi': 28.7, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 5070, 'id': 62425, 'gender': 'Female', 'age': 5.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 61.98, 'bmi': 16.8, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 5073, 'id': 17231, 'gender': 'Female', 'age': 24.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 90.42, 'bmi': 24.3, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 5078, 'id': 27446, 'gender': 'Female', 'age': 8.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Urban', 'avg_glucose_level': 76.31, 'bmi': 15.5, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 5080, 'id': 22691, 'gender': 'Female', 'age': 29.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Self-employed', 'Residence_type': 'Urban', 'avg_glucose_level': 90.52, 'bmi': 28.0, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 5083, 'id': 72914, 'gender': 'Female', 'age': 19.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 90.57, 'bmi': 24.2, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'normal'}
# {'Unnamed: 0': 5089, 'id': 56714, 'gender': 'Female', 'age': 0.72, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 62.13, 'bmi': 16.8, 'smoking_status': 'never smoked', 'stroke': 0, 'age_category': 'enfant', 'glucose_category': 'faible'}
# {'Unnamed: 0': 5103, 'id': 22127, 'gender': 'Female', 'age': 18.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 82.85, 'bmi': 46.9, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'adulte_21_45', 'glucose_category': 'faible'}
# {'Unnamed: 0': 5104, 'id': 14180, 'gender': 'Female', 'age': 13.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'No', 'work_type': 'children', 'Residence_type': 'Rural', 'avg_glucose_level': 103.08, 'bmi': 18.6, 'smoking_status': 'Unknown', 'stroke': 0, 'age_category': 'ado', 'glucose_category': 'normal'}

# %%
# test fonction sans argument max_age

# %% [markdown]
# Ajouter des valeurs par défault et les conditions pour chaque filtre.
#
# Pour les types, on indique qu'il s'agit de paramètres optionels en utilisant le module python _typing_
#
# ```
# from typing import Optional
# def filter_patient(stroke_data_df: pd.DataFrame, gender: Optional[str] = None,etc)
# ```
#
# Adapter les types en utilisant ce modèle.

# %%
# fonction avec ajout de paramètres par défault et de type

# %% [markdown]
# Tester la fonction sans argument pour les filtres, elle doit donc renvoyer le dataframe non filtré.

# %%
# test fonction sans argument pour les filtres

# %% [markdown]
# Cette fonction va être utilisée dans la définition de l'API pour créer une route qui permette d'accéder à des données filtrées sur les patients.
#
# Dans le fichier de définition de l'API, toutes les fonctions vont travailler sur les données du fichier.
#
# Pour alléger les fonctions on va donc utiliser une **variable globale** pour les données et supprimer le paramètre `df` de la fonction.
#
# On lit les données en début de fichier puis on travaille au sein des fonctions sur une copie du dataframe de données.
#
#
# **En résumé les modifications à faire sont :**
#
#
# - Supprimer le paramètre df de la fonction,
# - Ajouter en début de fonction :
# ```df = stroke_data_df.copy()```
#
# 1. Dans le fichier filters.py, il suffit d'ajouter :
# - lecture du fichier de données prétraitée dans la variable *df* en début de fichier (utiliser pandas),
# - @app.get("/patients/") pour définir le route,
# puis la fonction.
#
# 2. Dans le fichier api.py: appeler la fonction dans la route correspondante.
#
# Tester la route avec
#
# ```poetry run fastapi dev stroke_api/main.py```
#
# http://127.0.0.1:8000/docs : utiliser la fonctionnalité Try it out pour tester la route.

# %% [markdown]
# ---
# ## Autres routes
#
# De la même manière, créer les fonctions appropriées pour la création de :
# - la route `/patients/{id}` : Récupère les détails d’un patient donné (via son identifiant unique)
#
# - la route `/stats/` : Fournit des statistiques agrégées sur les patients (ex. : nb total de patients, âge moyen, taux d’AVC, répartition hommes/femmes).
#
# - Lister les tâches à faire sous forme d'issue github : travailler sur une branche différentes pour l'ajout de chacune des routes.
